# %%
import sys
import warnings

if not sys.warnoptions:
    warnings.simplefilter("ignore")

# %% [markdown]
# ## Importing the Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import matplotlib
plt.style.use('ggplot')
import warnings
import itertools
matplotlib.rcParams['axes.labelsize'] = 14
matplotlib.rcParams['xtick.labelsize'] = 12
matplotlib.rcParams['ytick.labelsize'] = 12
matplotlib.rcParams['text.color'] = 'k'

# %% [markdown]
# ## Input Data and extract required columns

# %%
# Load data
df = pd.read_csv('electricity generated renewables.csv')

df['Year'] = df['Year'].replace({'1st quarter':'Q1','2nd quarter':'Q2','3rd quarter':'Q3',
                                                                 '4th quarter':'Q4'}, regex=True)
df.head()
# Out:
#         Year Onshore Wind Offshore Wind  Shoreline wave / tidal   \
# 0  2010 \nQ1        1,757           671                        1
# 1  2010 \nQ2        1,199           460                        1
# 2  2010 \nQ3        1,934           826                        1
# 3  2010 \nQ4        2,336         1,103                        0
# 4  2011 \nQ1        2,397           998                        0
#
#   Solar photovoltaics  Hydro Landfill gas [note 6]  \
# 0                   6    845                 1,301
# 1                  11    654                 1,291
# 2                  15    856                 1,301
# 3                   9  1,237                 1,324
# 4                  15  1,304                 1,327
#
#    Sewage sludge digestion [note 6] Energy from waste [note 8]  \
# 0                               175                        378
# 1                               189                        383
# 2                               180                        378
# 3                               179                        390
# 4                               189                        378
#
#    Co-firing with fossil fuels  Animal Biomass (non-AD) [note 2] [note 6]  \
# 0                          579                                        167
# 1                          460                                        161
# 2                          678                                        143
# 3                          716                                        156
# 4                          828                                        159
#
#    Anaerobic Digestion Plant Biomass [note 3] [note 6]  \
# 0                   18                             352
# 1                   24                             421
# 2                   32                             414
# 3                   44                             428
# 4                   47                             433
#
#    Electricity generated_R  Unnamed: 14  Unnamed: 15
# 0                    6.249          NaN          NaN
# 1                    5.253          NaN          NaN
# 2                    6.757          NaN          NaN
# 3                    7.922          NaN          NaN
# 4                    8.075          NaN          NaN

# %%
df['Year']=df['Year'].replace("\n","",regex= True,)
df['Year']  = pd.PeriodIndex(df['Year'].str.replace(' ', ''), freq='Q').to_timestamp()
df.head()
# Out:
#         Year Onshore Wind Offshore Wind  Shoreline wave / tidal   \
# 0 2010-01-01        1,757           671                        1
# 1 2010-04-01        1,199           460                        1
# 2 2010-07-01        1,934           826                        1
# 3 2010-10-01        2,336         1,103                        0
# 4 2011-01-01        2,397           998                        0
#
#   Solar photovoltaics  Hydro Landfill gas [note 6]  \
# 0                   6    845                 1,301
# 1                  11    654                 1,291
# 2                  15    856                 1,301
# 3                   9  1,237                 1,324
# 4                  15  1,304                 1,327
#
#    Sewage sludge digestion [note 6] Energy from waste [note 8]  \
# 0                               175                        378
# 1                               189                        383
# 2                               180                        378
# 3                               179                        390
# 4                               189                        378
#
#    Co-firing with fossil fuels  Animal Biomass (non-AD) [note 2] [note 6]  \
# 0                          579                                        167
# 1                          460                                        161
# 2                          678                                        143
# 3                          716                                        156
# 4                          828                                        159
#
#    Anaerobic Digestion Plant Biomass [note 3] [note 6]  \
# 0                   18                             352
# 1                   24                             421
# 2                   32                             414
# 3                   44                             428
# 4                   47                             433
#
#    Electricity generated_R  Unnamed: 14  Unnamed: 15
# 0                    6.249          NaN          NaN
# 1                    5.253          NaN          NaN
# 2                    6.757          NaN          NaN
# 3                    7.922          NaN          NaN
# 4                    8.075          NaN          NaN

# %%
# shift column 'Name' to first position
first_column = df.pop('Year')
df.insert(0, 'Year', first_column)

# %%
df['Year'] = pd.to_datetime(df['Year'], format = '%Y')
df.set_index('Year', inplace=True)  # Set 'date' as index
df.head()
# Out:
#            Onshore Wind Offshore Wind  Shoreline wave / tidal   \
# Year
# 2010-01-01        1,757           671                        1
# 2010-04-01        1,199           460                        1
# 2010-07-01        1,934           826                        1
# 2010-10-01        2,336         1,103                        0
# 2011-01-01        2,397           998                        0
#
#            Solar photovoltaics  Hydro Landfill gas [note 6]  \
# Year
# 2010-01-01                   6    845                 1,301
# 2010-04-01                  11    654                 1,291
# 2010-07-01                  15    856                 1,301
# 2010-10-01                   9  1,237                 1,324
# 2011-01-01                  15  1,304                 1,327
#
#             Sewage sludge digestion [note 6] Energy from waste [note 8]  \
# Year
# 2010-01-01                               175                        378
# 2010-04-01                               189                        383
# 2010-07-01                               180                        378
# 2010-10-01                               179                        390
# 2011-01-01                               189                        378
#
#             Co-firing with fossil fuels  \
# Year
# 2010-01-01                          579
# 2010-04-01                          460
# 2010-07-01                          678
# 2010-10-01                          716
# 2011-01-01                          828
#
#             Animal Biomass (non-AD) [note 2] [note 6]  Anaerobic Digestion  \
# Year
# 2010-01-01                                        167                   18
# 2010-04-01                                        161                   24
# 2010-07-01                                        143                   32
# 2010-10-01                                        156                   44
# 2011-01-01                                        159                   47
#
#            Plant Biomass [note 3] [note 6]  Electricity generated_R  \
# Year
# 2010-01-01                             352                    6.249
# 2010-04-01                             421                    5.253
# 2010-07-01                             414                    6.757
# 2010-10-01                             428                    7.922
# 2011-01-01                             433                    8.075
#
#             Unnamed: 14  Unnamed: 15
# Year
# 2010-01-01          NaN          NaN
# 2010-04-01          NaN          NaN
# 2010-07-01          NaN          NaN
# 2010-10-01          NaN          NaN
# 2011-01-01          NaN          NaN

# %% [markdown]
# ## Checking info

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 51 entries, 2010-01-01 to 2022-07-01
# Data columns (total 15 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Onshore Wind                               51 non-null     object
#  1   Offshore Wind                              51 non-null     object
#  2   Shoreline wave / tidal                     51 non-null     int64
#  3   Solar photovoltaics                        51 non-null     object
#  4   Hydro                                      51 non-null     object
#  5   Landfill gas [note 6]                      51 non-null     object
#  6   Sewage sludge digestion [note 6]           51 non-null     int64
#  7   Energy from waste [note 8]                 51 non-null     object
#  8   Co-firing with fossil fuels                51 non-null     int64
#  9   Animal Biomass (non-AD) [note 2] [note 6]  51 non-null     int64
#  10  Anaerobic Digestion                        51 non-null     int64
#  11  Plant Biomass [note 3] [note 6]            51 non-null     object
#  12  Electricity generated_R                    51 non-null     float64
#  13  Unnamed: 14                                0 non-null      float64
#  14  Unnamed: 15                                0 non-null      float64
# dtypes: float64(3), int64(5), object(7)
# memory usage: 6.4+ KB

# %% [markdown]
# ## Extracting the required column

# %%
df=df[['Electricity generated_R']]
df.head()
# Out:
#             Electricity generated_R
# Year
# 2010-01-01                    6.249
# 2010-04-01                    5.253
# 2010-07-01                    6.757
# 2010-10-01                    7.922
# 2011-01-01                    8.075

# %% [markdown]
# ## Let's Visualise Electricity generated in each year

# %%
df.plot(figsize=(15, 6))
plt.show()

# %% [markdown]
# ### Visualise the data using time-series decomposition that allows us to decompose our time series into three distinct components: trend, seasonality, and noise.

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize'] = 16, 10
decomposition = sm.tsa.seasonal_decompose(df, model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# ## Autocorrelation Function (ACF) and Partial Autocorrelation Function (PACF).
# ### The ACF and PACF are used to figure out the order of AR, MA, and ARMA models.

# %%
from statsmodels.tsa.stattools import adfuller,acf, pacf

# %%
def stationarity_test(timeseries):
    # Get rolling statistics for window = 12 i.e. yearly statistics
    rolling_mean = timeseries.rolling(window = 12).mean()
    rolling_std = timeseries.rolling(window = 12).std()
    
    # Plot rolling statistic
    plt.figure(figsize= (10,6))
    plt.xlabel('Years')
    plt.ylabel('Electricity generated_R')    
    plt.title('Stationary Test: Rolling Mean and Standard Deviation')
    plt.plot(timeseries, color= 'blue', label= 'Original')
    plt.plot(rolling_mean, color= 'green', label= 'Rolling Mean')
    plt.plot(rolling_std, color= 'red', label= 'Rolling Std')   
    plt.legend()
    plt.show()
    # Dickey-Fuller test
    print('Results of Dickey-Fuller Test')
    df_test = adfuller(timeseries)
    df_output = pd.Series(df_test[0:4], index = ['Test Statistic', 'p-value', '#Lags Used', 'Number of Observations Used'])
    for key, value in df_test[4].items():
        df_output['Critical Value (%s)' %key] = value
    print(df_output)

# %% [markdown]
# #### Meaning of Stationary
#
# 1. Stationarity means that the statistical properties of a a time series (or rather the process generating it) do not change over time.
# 2. Stationarity is important because many useful analytical tools and statistical tests and models rely on it.

# %%
# Lets test the stationarity score with original series data
stationarity_test(df)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -1.143845
# p-value                         0.697274
# #Lags Used                      7.000000
# Number of Observations Used    43.000000
# Critical Value (1%)            -3.592504
# Critical Value (5%)            -2.931550
# Critical Value (10%)           -2.604066
# dtype: float64

# %% [markdown]
# Convert Non-Stationary Data to Stationary Data
# Let's first use the differencing technique to obtain the stationarity.
#
# Differencing
# To transform the series using 'Differencing' we will use the diff() method of pandas. A benefit of using the Pandas function, in addition to requiring less code, is that it maintains the date-time information for the differenced series

# %% [markdown]
# `Differencing can help stabilise the mean of a time series by removing changes in the level of a time series, and therefore eliminating (or reducing) trend and seasonality.`

# %%
df_diff = df.diff(periods = 1) # First order differencing
plt.xlabel('Years')
plt.ylabel('Electricity generated_R')    
plt.title('Convert Non Stationary Data to Stationary Data using Differencing ')
plt.plot(df_diff)

# %%
df_diff.dropna(inplace = True)# Data transformation may add na values
stationarity_test(df_diff)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -4.204808
# p-value                         0.000647
# #Lags Used                      6.000000
# Number of Observations Used    43.000000
# Critical Value (1%)            -3.592504
# Critical Value (5%)            -2.931550
# Critical Value (10%)           -2.604066
# dtype: float64

# %% [markdown]
# 1. For forecasting and economic analysis many variables are used in logarithms (logs).
# 2. In time series analysis this transformation is often considered to stabilize the variance of a series.

# %%
df_log = np.log(df)

plt.subplot(211)
plt.plot(df, label= 'Time Series with Variance')
plt.legend()
plt.subplot(212)
plt.plot(df_log, label='Time Series without Variance (Log Transformation)')
plt.legend()  
plt.show()

# %% [markdown]
# ### Differencing in Time Series
# 1. The first difference of a time series is the series of changes from one period to the next.
# 2. If Yt denotes the value of the time series Y at period t, then the first difference of Y at period t is equal to Yt-Yt-1.

# %%
df_log_diff = df_log.diff(periods = 1) # First order differencing

df_log_diff.dropna(inplace = True)# Data transformation may add na values
stationarity_test(df_log_diff)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -1.271767
# p-value                         0.641988
# #Lags Used                      8.000000
# Number of Observations Used    41.000000
# Critical Value (1%)            -3.600983
# Critical Value (5%)            -2.935135
# Critical Value (10%)           -2.605963
# dtype: float64

# %% [markdown]
# #### Moving Average
# 1. Since we have time series data from 1970 to 2021, we will define a yearly window for moving average.
# 2. Window size = 12.
# 3. Note that we are going to use Log transformed data.

# %%
df_log_moving_avg = df_log.rolling(window = 12).mean()
plt.xlabel('Years')
plt.ylabel('Electricity generated_R')    
plt.title('Convert Non Stationary Data to Stationary Data using Moving Average')
plt.plot(df_log, color= 'blue', label='Orignal')
plt.plot(df_log_moving_avg, color= 'red', label='Moving Average')
plt.legend()

# %%
df_log_moving_avg_diff = df_log - df_log_moving_avg
df_log_moving_avg_diff.dropna(inplace = True)
stationarity_test(df_log_moving_avg_diff)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -0.761676
# p-value                         0.830121
# #Lags Used                      6.000000
# Number of Observations Used    33.000000
# Critical Value (1%)            -3.646135
# Critical Value (5%)            -2.954127
# Critical Value (10%)           -2.615968
# dtype: float64

# %% [markdown]
# ### Weighted Moving Average (WMA)
# 1. Here we are going to use exponentially weighted moving average with parameter ‘halflife = 12’.
# 2. This parameter defines the amount of exponential decay.

# %%
df_log_weighted_avg = df_log.ewm(halflife = 12).mean()
plt.plot(df_log)
plt.plot(df_log_weighted_avg, color = 'blue')

# %%
df_log_weighted_avg_diff = df_log - df_log_weighted_avg
stationarity_test(df_log_weighted_avg_diff)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -1.815111
# p-value                         0.372986
# #Lags Used                      7.000000
# Number of Observations Used    43.000000
# Critical Value (1%)            -3.592504
# Critical Value (5%)            -2.931550
# Critical Value (10%)           -2.604066
# dtype: float64

# %% [markdown]
# #### Decomposition of Time Series
#
# 1. The decomposition of time series is a statistical task that deconstructs a time series into several components, each representing one of the underlying categories of patterns.
#
# 2. Let's now use the decomposition technique to deconstruct the log transformed time series data, so that we can check the stationarity using residual data.

# %%
decomposition = sm.tsa.seasonal_decompose(df_log,period =12)
fig = decomposition.plot()

# %% [markdown]
# Here we can see that the trend and seasonality are separated out from log transformed data, and we can now check the stationarity of the residuals

# %% [markdown]
# 1. The “residuals” in a time series model are what is left over after fitting a model.
# 2. For many (but not all) time series models, the residuals are equal to the difference between the observations
#    and the corresponding fitted values: et=yt−y_t.

# %%
df_log_residual = decomposition.resid
df_log_residual.dropna(inplace = True)
stationarity_test(df_log_residual)
# Out:
# Results of Dickey-Fuller Test
# Test Statistic                 -5.072057
# p-value                         0.000016
# #Lags Used                      0.000000
# Number of Observations Used    38.000000
# Critical Value (1%)            -3.615509
# Critical Value (5%)            -2.941262
# Critical Value (10%)           -2.609200
# dtype: float64

# %% [markdown]
# ### ACF and PACF Plots
# 1. To figure out the order of AR model(p) we will use PACF function.
# 2. p = the lag value where the PACF chart crosses the upper confidence interval for the first time
# 3. To figure out the order of MA model(q) we will use ACF function.
# 4. q = the lag value where the ACF chart crosses the upper confidence interval for the first time

# %%
lag_acf = acf(df_log_diff, nlags=20)
lag_pacf = pacf(df_log_diff, nlags=20, method='ols')

# Plot ACF: 
plt.subplot(121) 
plt.plot(lag_acf)
plt.axhline(y=0,linestyle='--',color='gray')
# Draw 95% confidence interval line
plt.axhline(y=-1.96/np.sqrt(len(df_log_diff)),linestyle='--',color='red')
plt.axhline(y=1.96/np.sqrt(len(df_log_diff)),linestyle='--',color='red')
plt.xlabel('Lags')
plt.title('Autocorrelation Function')

#Plot PACF:
plt.subplot(122)
plt.plot(lag_pacf)
plt.axhline(y=0,linestyle='--',color='gray')
# Draw 95% confidence interval line
plt.axhline(y=-1.96/np.sqrt(len(df_log_diff)),linestyle='--',color='red')
plt.axhline(y=1.96/np.sqrt(len(df_log_diff)),linestyle='--',color='red')
plt.xlabel('Lags')
plt.title('Partial Autocorrelation Function')
plt.tight_layout()

# %% [markdown]
# #### To make a better explanation of ARIMA we can also write it as (AR, I, MA) and by this, we can assume that in the ARIMA, p is AR, d is I and q is MA. These parameters can be explained as follows:
#
# 1. p is the number of autoregressive terms,
# 2. d is the number of nonseasonal differences,
# 3. q is the number of lagged forecast errors in the prediction equation.

# %% [markdown]
# ### How to choose values of p, d and q?
# ##### There are various ways to choose the values of parameters of the ARIMA model. Without being confused we can do this using the following steps:
#
# 1. Test for stationarity using the augmented dickey fuller test.
# 2. If the time series is stationary try to fit the ARMA model, and if the time series is non-stationary then seek the value of d.
# 3. If the data is getting stationary then draw the autocorrelation and partial autocorrelation graph of the data.
# 4. Draw a partial autocorrelation graph(ACF) of the data. This will help us in finding the value of p because the cut-off point to the PACF is p.
# 5. Draw an autocorrelation graph(ACF) of the data. This will help us in finding the value of q because the cut-off point to the ACF is q.

# %%
p = d = q = range(0, 2)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
print('Examples of parameter combinations for Seasonal ARIMA...')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of parameter combinations for Seasonal ARIMA...
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# This step is parameter Selection for our ARIMA Time Series Model. Our goal here is to use a “grid search” to find the optimal set of parameters that yields the best performance for our model.

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            enforce_invertibility=False)

            results = mod.fit()
            
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.55473D+00    |proj g|=  1.88294D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      0      1      0     0     0   1.883D-08   4.555D+00
#   F =   4.5547303294343031
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:466.5824936022989
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.75917D+00    |proj g|=  6.22763D-01
#
# At iterate    5    f=  4.50859D+00    |proj g|=  2.09415D-01
#
# At iterate   10    f=  4.18787D+00    |proj g|=  2.45846D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     13     16      1     0     0   7.694D-06   4.188D+00
#   F =   4.1877299507447869
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:431.14845497596826
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.68825D+00    |proj g|=  3.37242D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      3      4      1     0     0   4.974D-09   2.673D+00
#   F =   2.6731717626738991
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:274.6635197927377
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.58413D+01    |proj g|=  4.15498D-01
#   ys=-2.911E+01  -gs= 7.456E-01 BFGS update SKIPPED
#   ys=-2.110E-01  -gs= 1.805E-01 BFGS update SKIPPED
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     83      2     2     0   4.131D+05   1.244D+01
#   F =   12.435914937388830
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:1272.4633236136606
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.32973D+01    |proj g|=  1.51069D+01
#
# At iterate    5    f=  3.88131D+00    |proj g|=  1.65730D-01
#
# At iterate   10    f=  3.74175D+00    |proj g|=  2.60036D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     14     15      1     0     0   1.140D-07   3.742D+00
#   F =   3.7416287587815851
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:385.6461333957217
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.13924D+01    |proj g|=  3.97861D+01
#
# At iterate    5    f=  4.13431D+00    |proj g|=  3.75792D-01
#
# At iterate   10    f=  3.91373D+00    |proj g|=  5.06804D-02
#
# At iterate   15    f=  3.84122D+00    |proj g|=  4.25716D-02
#
# At iterate   20    f=  3.79537D+00    |proj g|=  1.10526D-01
#
# At iterate   25    f=  3.77319D+00    |proj g|=  5.67361D-02
#
# At iterate   30    f=  3.76305D+00    |proj g|=  2.15461D-01
#
# At iterate   35    f=  3.75587D+00    |proj g|=  1.31360D-01
#
# At iterate   40    f=  3.75151D+00    |proj g|=  1.32988D-01
#
# At iterate   45    f=  3.74923D+00    |proj g|=  2.91087D-01
#
# At iterate   50    f=  3.74728D+00    |proj g|=  3.67933D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     60      1     0     0   3.679D-02   3.747D+00
#   F =   3.7472759273486833
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:388.2221445895657
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.37713D+00    |proj g|=  6.21426D-02
#
# At iterate    5    f=  2.36831D+00    |proj g|=  3.73102D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5      7      1     0     0   3.731D-06   2.368D+00
#   F =   2.3683128566443412
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:245.56791137772282
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.57216D+01    |proj g|=  2.21367D-01
#   ys=-7.200E+01  -gs= 7.568E-01 BFGS update SKIPPED
#   ys=-1.533E-02  -gs= 1.409E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     81      3     2     0   2.940D+05   1.301D+01
#   F =   13.013098903531864
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:1333.33608816025
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.23958D+00    |proj g|=  1.73961D-01
#
# At iterate    5    f=  4.16862D+00    |proj g|=  3.10214D-02
#
# At iterate   10    f=  3.94758D+00    |proj g|=  4.97342D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     12     19      1     0     0   2.165D-06   3.947D+00
#   F =   3.9473352731875431
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:406.6281978651294
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.30363D+00    |proj g|=  3.50230D-01
#
# At iterate    5    f=  4.16748D+00    |proj g|=  1.24404D-01
#
# At iterate   10    f=  3.65656D+00    |proj g|=  3.57669D-01
#
# At iterate   15    f=  3.60031D+00    |proj g|=  1.16407D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     22      1     0     0   2.281D-07   3.600D+00
#   F =   3.6002851170522492
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:373.22908193932943
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.42952D+00    |proj g|=  1.20649D-01
#
# At iterate    5    f=  2.32795D+00    |proj g|=  2.95330D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6     14      1     0     0   1.539D-07   2.328D+00
#   F =   2.3279547021405573
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:241.45137961833683
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.69203D+01    |proj g|=  1.01349D-01
#   ys=-1.012E+02  -gs= 7.590E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     82      2     1     0   2.935D+03   1.603D+01
#   F =   16.025972451728304
#
# ABNORMAL_TERMINATION_IN_LNSRCH
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:1640.649190076287
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.23958D+00    |proj g|=  1.90894D-01
#
# At iterate    5    f=  4.15157D+00    |proj g|=  4.63060D-02
#
# At iterate   10    f=  3.51985D+00    |proj g|=  5.13101D-01
#
# At iterate   15    f=  3.26209D+00    |proj g|=  9.40232D-02
#
# At iterate   20    f=  3.25860D+00    |proj g|=  5.13344D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21     33      1     0     0   2.844D-06   3.259D+00
#   F =   3.2585956844791308
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:338.37675981687136
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.65370D+00    |proj g|=  4.46830D-01
#
# At iterate    5    f=  4.18587D+00    |proj g|=  4.35996D-02
#
# At iterate   10    f=  3.91683D+00    |proj g|=  5.29616D-01
#
# At iterate   15    f=  3.16430D+00    |proj g|=  1.10727D-01
#
# At iterate   20    f=  3.16202D+00    |proj g|=  6.90062D-03
#
# At iterate   25    f=  3.16153D+00    |proj g|=  7.02691D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     28     42      1     0     0   8.909D-06   3.162D+00
#   F =   3.1615342212108750
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:330.47649056350923
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.45911D+00    |proj g|=  1.03064D-01
#
# At iterate    5    f=  2.25347D+00    |proj g|=  2.51406D-01
#
# At iterate   10    f=  2.18049D+00    |proj g|=  1.34177D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     13     15      1     0     0   4.251D-06   2.180D+00
#   F =   2.1804850540991398
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:228.40947551811226
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.63201D+01    |proj g|=  1.01349D-01
#   ys=-3.550E+00  -gs= 6.879E-01 BFGS update SKIPPED
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      4     70      2     1     0   1.403D+05   1.462D+01
#   F =   14.617505428664387
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:1498.9855537237675
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.80173D+00    |proj g|=  4.69724D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      4      1     0     0   8.149D-06   2.802D+00
#   F =   2.8016371919980680
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:287.76699358380296
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.06326D+00    |proj g|=  5.02559D-01
#
# At iterate    5    f=  2.72837D+00    |proj g|=  2.75190D-01
#
# At iterate   10    f=  2.69080D+00    |proj g|=  1.44197D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     11     12      1     0     0   1.925D-06   2.691D+00
#   F =   2.6908025397453512
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:278.4618590540258
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.94982D+00    |proj g|=  9.12852D-02
#
# At iterate    5    f=  1.93199D+00    |proj g|=  1.46744D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      6      7      1     0     0   1.859D-06   1.932D+00
#   F =   1.9319907996764654
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:199.06306156699947
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.50679D+01    |proj g|=  1.15403D+01
#   ys=-3.493E+01  -gs= 7.298E-01 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4     71      2     1     0   6.579D+04   1.762D+01
#   F =   17.615615066257483
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:1800.7927367582631
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.88932D+00    |proj g|=  7.72827D-01
#
# At iterate    5    f=  2.57564D+00    |proj g|=  5.78982D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      8      9      1     0     0   3.989D-06   2.576D+00
#   F =   2.5755473197856027
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:266.7058266181315
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.79774D+00    |proj g|=  1.65631D+00
#
# At iterate    5    f=  2.58387D+00    |proj g|=  1.17900D-01
#
# At iterate   10    f=  2.57145D+00    |proj g|=  2.94652D-02
#
# At iterate   15    f=  2.55985D+00    |proj g|=  5.15939D-02
#
# At iterate   20    f=  2.55690D+00    |proj g|=  2.23717D-03
#
# At iterate   25    f=  2.55657D+00    |proj g|=  1.45853D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     27     29      1     0     0   8.334D-06   2.557D+00
#   F =   2.5565688656680368
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:266.77002429813973
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.89543D+00    |proj g|=  3.03751D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      4      6      1     0     0   4.485D-06   1.893D+00
#   F =   1.8926020871429547
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:197.04541288858138
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.32247D+00    |proj g|=  3.33297D+00
#
# At iterate    5    f=  1.88522D+00    |proj g|=  2.64318D-02
#
# At iterate   10    f=  1.87578D+00    |proj g|=  4.50418D-03
#
# At iterate   15    f=  1.87565D+00    |proj g|=  6.10791D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     16     17      1     0     0   2.386D-06   1.876D+00
#   F =   1.8756458105769536
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:197.31587267884927
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.75860D+00    |proj g|=  1.46819D-01
#
# At iterate    5    f=  2.72968D+00    |proj g|=  2.10311D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      7     10      1     0     0   3.822D-06   2.730D+00
#   F =   2.7296769690652511
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:282.42705084465564
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.01364D+00    |proj g|=  9.08236D-01
#
# At iterate    5    f=  2.62323D+00    |proj g|=  7.17372D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     12      1     0     0   4.979D-06   2.619D+00
#   F =   2.6194555834443110
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:273.1844695113197
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.91220D+00    |proj g|=  7.44508D-02
#
# At iterate    5    f=  1.89805D+00    |proj g|=  3.02235D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6      9      1     0     0   6.354D-07   1.898D+00
#   F =   1.8980508606945428
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:197.60118779084337
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.79600D+01    |proj g|=  2.37976D-01
#   ys=-2.627E+01  -gs= 7.251E-01 BFGS update SKIPPED
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/base/model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      4     64      3     1     0   2.931D+04   1.785D+01
#   F =   17.854035436209347
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:1827.1116144933535
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.75860D+00    |proj g|=  3.98643D-01
#
# At iterate    5    f=  2.52089D+00    |proj g|=  5.24567D-02
#
# At iterate   10    f=  2.51680D+00    |proj g|=  8.01394D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     12      1     0     0   4.987D-06   2.517D+00
#   F =   2.5167984331096571
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:262.713440177185
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28866D+00    |proj g|=  6.85095D-01
#
# At iterate    5    f=  2.53776D+00    |proj g|=  1.00487D-01
#
# At iterate   10    f=  2.49731D+00    |proj g|=  5.96318D-03
#
# At iterate   15    f=  2.49626D+00    |proj g|=  1.41436D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     17     19      1     0     0   2.107D-06   2.496D+00
#   F =   2.4962634501016399
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:262.61887191036726
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.87669D+00    |proj g|=  6.56890D-02
#
# At iterate    5    f=  1.85724D+00    |proj g|=  1.04875D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# ...
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:1812.705629549795
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.79896D+00    |proj g|=  4.41800D-01
#
# At iterate    5    f=  2.56986D+00    |proj g|=  2.14829D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     12      1     0     0   4.868D-06   2.569D+00
#   F =   2.5690279955933200
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:268.04085555051864
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.35442D+00    |proj g|=  7.31002D-01
#
# At iterate    5    f=  2.55740D+00    |proj g|=  5.99691D-02
#
# At iterate   10    f=  2.54877D+00    |proj g|=  5.07707D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     14     18      1     0     0   9.113D-07   2.549D+00
#   F =   2.5487318495921376
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:267.97064865839803
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.89055D+00    |proj g|=  4.28547D-02
#
# At iterate    5    f=  1.88263D+00    |proj g|=  1.07103D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      6      8      1     0     0   8.419D-07   1.883D+00
#   F =   1.8826290378661767
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:198.02816186235003
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.92421D+00    |proj g|=  1.73750D-01
#
# At iterate    5    f=  1.86883D+00    |proj g|=  4.49448D-02
#
# At iterate   10    f=  1.86676D+00    |proj g|=  3.44503D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     13     17      1     0     0   8.833D-06   1.867D+00
#   F =   1.8667425248495007
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:198.40773753464907
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.72895D+00    |proj g|=  1.45491D-01
#
# At iterate    5    f=  2.71363D+00    |proj g|=  1.40174D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     13      1     0     0   2.104D-05   2.713D+00
#   F =   2.7134283134052408
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:282.76968796733456
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97312D+00    |proj g|=  8.69559D-01
#
# At iterate    5    f=  2.62601D+00    |proj g|=  6.18141D-02
#
# At iterate   10    f=  2.60014D+00    |proj g|=  2.10702D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     13     14      1     0     0   8.148D-06   2.600D+00
#   F =   2.6001395510658081
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:273.2142342087124
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88395D+00    |proj g|=  1.56755D-01
#
# At iterate    5    f=  1.86862D+00    |proj g|=  6.12086D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      9     14      1     0     0   7.807D-07   1.869D+00
#   F =   1.8685130707666588
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:196.5883332181992
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.79326D+01    |proj g|=  2.46909D-01
#   ys=-6.188E+01  -gs= 7.364E-01 BFGS update SKIPPED
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate    5    f=  1.80149D+01    |proj g|=  3.40422D+00
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      7     35      2     1     0   1.279D-03   1.801D+01
#   F =   18.014932505315993
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:1845.5231155422312
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.72895D+00    |proj g|=  3.81081D-01
#
# At iterate    5    f=  2.49582D+00    |proj g|=  3.33752D-02
#
# At iterate   10    f=  2.49045D+00    |proj g|=  1.48524D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     12     16      1     0     0   6.516D-06   2.490D+00
#   F =   2.4904539117347881
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:262.0262989969484
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.24500D+00    |proj g|=  6.62909D-01
#
# At iterate    5    f=  2.77731D+00    |proj g|=  1.15920D-01
#
# At iterate   10    f=  2.51134D+00    |proj g|=  2.38767D-01
#
# At iterate   15    f=  2.50189D+00    |proj g|=  1.02571D-02
#
# At iterate   20    f=  2.49006D+00    |proj g|=  5.28819D-02
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# At iterate   25    f=  2.48200D+00    |proj g|=  4.76757D-02
#
# At iterate   30    f=  2.47304D+00    |proj g|=  1.48379D-02
#
# At iterate   35    f=  2.47210D+00    |proj g|=  1.15978D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     39     49      1     0     0   1.941D-05   2.472D+00
#   F =   2.4720586648083640
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:262.14998381045314
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.85301D+00    |proj g|=  9.34070D-02
#
# At iterate    5    f=  1.83468D+00    |proj g|=  1.98399D-02
#
# At iterate   10    f=  1.83371D+00    |proj g|=  2.64109D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     14      1     0     0   3.340D-06   1.834D+00
#   F =   1.8337070331364651
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:195.03811737991944
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88395D+00    |proj g|=  1.69618D-01
#
# At iterate    5    f=  1.83410D+00    |proj g|=  1.53950D-02
#
# At iterate   10    f=  1.82771D+00    |proj g|=  3.33751D-03
#
# At iterate   15    f=  1.82770D+00    |proj g|=  2.31053D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     16     19      1     0     0   1.167D-05   1.828D+00
#   F =   1.8277028275215497
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:196.42568840719807
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.

# %% [markdown]
# The above output suggests that SARIMAX (1, 1, 1)x(1, 1, 1, 12) yields the lowest AIC value of 592.58. Therefore we should consider this to be optimal option.

# %% [markdown]
# **Fitting the ARIMA model**

# %%
mod = sm.tsa.statespace.SARIMAX(df,
                                order=(1, 1, 1),
                                seasonal_order=(1, 1, 1, 12),
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
# /opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency QS-OCT will be used.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  1.88395D+00    |proj g|=  1.69618D-01
#
# At iterate    5    f=  1.83410D+00    |proj g|=  1.53950D-02
#
# At iterate   10    f=  1.82771D+00    |proj g|=  3.33751D-03
#
# At iterate   15    f=  1.82770D+00    |proj g|=  2.31053D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     16     19      1     0     0   1.167D-05   1.828D+00
#   F =   1.8277028275215497
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.4342      0.359      1.208      0.227      -0.270       1.138
# ma.L1         -0.7981      0.288     -2.773      0.006      -1.362      -0.234
# ar.S.L12      -0.7017      0.433     -1.620      0.105      -1.550       0.147
# ma.S.L12       0.3547      0.589      0.602      0.547      -0.800       1.510
# sigma2         7.2530      2.170      3.343      0.001       3.000      11.506
# ==============================================================================

# %% [markdown]
# We need to always run model diagnostics to investigate any unusual behavior.

# %%
results.plot_diagnostics(lags=4)
plt.show()

# %% [markdown]
# 1. Standardized residual for 'E' :
#    A standardized residual is the raw residuals divided by an overall standard deviation of the raw residuals. This      provides a consistent measure of the error of your prediction.
#
# 2. Histogram plus estimated density :
#    A density plot can be seen as an extension of the histogram. As opposed to the histogram, the density plot can
#    smooth out the distribution of values and reduce the noise. It visualizes the distribution of data over a given
#    period, and the peaks show where values are concentrated.
#
# 3. Normal Q-Q :
#    A Quantile-Quantile plot (QQ-plot) shows the "match" of an observed distribution with a theoretical distribution,      almost always the normal distribution
#
# 4. correlogram :
#    A correlogram, also known as Auto Correlation Function (ACF) plot, is a graphic way to demonstrate serial
#    correlation in data that doesn't remain constant with time. A correlogram gives a fair idea of auto-correlation
#    between data pairs at different time periods.

# %% [markdown]
# **Evaluation of Forecasts**

# %% [markdown]
# In order to understand the accuracy of our forecasts, we compare `predicted Electricity generated` to `actual Electricity generated` of the time series, and we set forecasts to start at `2015–01–01` to the end of the data.

# %%
pred = results.get_prediction(start=pd.to_datetime('2015-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = df['2020':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.9, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Electricity generated_R')
plt.legend()
plt.show()

# %% [markdown]
# Let's find out the MSE to see the accuracy of our model.
# The mean squared error (MSE) is largely used as a metric to determine the performance of an algorithm. In addition, MSE is the average of the square of the difference between the observed and predicted values of a variable.

# %%
y_forecasted = pred.predicted_mean
y_truth = df['2010-01-01':]['Electricity generated_R']
rmse=np.sqrt(mse_SARIMA)
print('The Mean Squared Error of our forecasts is {}'.format(round(mse_SARIMA, 2)))
print('The Root Mean Squared Error of our forecasts is {}'.format(round(rmse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 7.7
# The Root Mean Squared Error of our forecasts is 2.78

# %% [markdown]
# **Visualising Forecasts**

# %% [markdown]
# As we can see in the below graph the `Electricity Generated through renewable resources` in UK will be increasing in next years

# %%
pred_uc = results.get_forecast(steps=100)
pred_ci = pred_uc.conf_int()
ax = df.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='r', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Electricity generated_R')
plt.legend()
plt.show()
